# %%
from bs4 import BeautifulSoup
import requests

# %%
url = "https://de.wikipedia.org/wiki/Liste_der_gr%C3%B6%C3%9Ften_Unternehmen_in_Deutschland_(Wertsch%C3%B6pfung)"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, "html")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="de">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Liste der größten Unternehmen in Deutschland (Wertschöpfung) – Wikipedia
#   </title>
#   <script>
# ...

# %%
table = soup.find_all("table")[0]

# %%
print(table)
# Out:
# <table class="wikitable sortable" style="text-align:right">
# <caption>
# </caption>
# <tbody><tr>
# <th>Rang<br/> 2020</th>
# <th>
# </th>
# <th>Rang<br/> 2018</th>
# <th>Unternehmen
# </th>
# <th>Hauptsitz</th>
# <th data-sort-type="number">Wertschöpfung<br/> (in Mio. €)</th>
# <th data-sort-type="number">Beschäftigte</th>
# <th data-sort-type="number">Geschäftsvolumen<br/> (in Mio. €)
# </th></tr>
# <tr>
# <td>1.</td>
# <td data-sort-value="1"><span title="unverändert"> <span aria-hidden="true" role="presentation" style="color:#00AAFF;position:relative;left:-0.2em;">▬</span></span>
# </td>
# <td>1.</td>
# <td style="text-align:left"><a href="/wiki/Volkswagen_AG" title="Volkswagen AG">Volkswagen AG</a>
# </td>
# <td><a href="/wiki/Wolfsburg" title="Wolfsburg">Wolfsburg</a></td>
# <td>28.697</td>
# <td>294.510</td>
# <td>145.285
# </td></tr>
# <tr>
# <td>2.</td>
# ...

# %%
world_titles = table.find_all("th")

# %%
world_titles
# Out:
# [<th>Rang<br/> 2020</th>,
#  <th>
#  </th>,
#  <th>Rang<br/> 2018</th>,
#  <th>Unternehmen
#  </th>,
#  <th>Hauptsitz</th>,
#  <th data-sort-type="number">Wertschöpfung<br/> (in Mio. €)</th>,
#  <th data-sort-type="number">Beschäftigte</th>,
#  <th data-sort-type="number">Geschäftsvolumen<br/> (in Mio. €)
#  </th>]

# %%
world_table_titles = [title.text.strip() for title in world_titles]

# %%
print(world_table_titles)
# Out:
# ['Rang 2020', '', 'Rang 2018', 'Unternehmen', 'Hauptsitz', 'Wertschöpfung (in Mio. €)', 'Beschäftigte', 'Geschäftsvolumen (in Mio. €)']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns= world_table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rang 2020, , Rang 2018, Unternehmen, Hauptsitz, Wertschöpfung (in Mio. €), Beschäftigte, Geschäftsvolumen (in Mio. €)]
# Index: []

# %%
column_data = table.find_all("tr")

# %%
for row in column_data[1:]:
    row_data = row.find_all("td")
    individual_row_data = [data.text.strip() for data in row_data]
    
    lenght = len(df)
    df.loc[lenght] = individual_row_data

# %%
df
# Out:
#    Rang 2020    Rang 2018                              Unternehmen  \
# 0         1.  ▬        1.                            Volkswagen AG
# 1         2.  ▬        2.                               Daimler AG
# 2         3.  ▲        6.                               Siemens AG
# 3         4.  ▲        7.                      Deutsche Telekom AG
# 4         5.  ▬        5.                        Robert Bosch GmbH
# ..       ... ..       ...                                      ...
# 95       96.  ▼       82.                            Debeka-Gruppe
# 96       97.  ▲         -                         Rhön-Klinikum AG
# 97       98.  ▲         -                 Drägerwerk AG & CO. KGaA
# 98       99.  ▲         -            Telefónica-Gruppe Deutschland
# 99      100.  ▼       74.  Vivantes – Netzwerk für Gesundheit GmbH
#
#                     Hauptsitz Wertschöpfung (in Mio. €) Beschäftigte  \
# 0                   Wolfsburg                    28.697      294.510
# ...

# %%
df.to_csv(r"/Users/install/pythonProject/WebscrapingTest/results/test.csv", index=False)
